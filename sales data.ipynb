# %%
pip install ipython-sql sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pymysql
# Out:
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:1234@localhost:3306/sales_data"
)

# %%
connection = engine.connect()
print("MySQL Connected Successfully!")
connection.close()
# Out:
# MySQL Connected Successfully!

# %%
orders = pd.read_sql("SELECT * FROM orders", engine)
order_items = pd.read_sql("SELECT * FROM order_items", engine)
customers = pd.read_sql("SELECT * FROM customers", engine)

print(orders.head())
print(order_items.head())
print(customers.head())
# Out:
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  01-01-2016    03-01-2016   03-01-2016
# 1         2         1212             4  01-01-2016    04-01-2016   03-01-2016
# 2         3          523             4  02-01-2016    05-01-2016   03-01-2016
# 3         4          175             4  03-01-2016    04-01-2016   05-01-2016
# 4         5         1324             4  03-01-2016    06-01-2016   06-01-2016
#
#    store_id  staff_id order_details
# 0         1         2     DELIVERED
# 1         2         6     DELIVERED
# 2         2         7     DELIVERED
# 3         1         3     DELIVERED
# 4         2         6     DELIVERED
#    order_id  item_id  product_id  quantity  list_price  discount    sales  \
# 0         1        1          20         1      599.99      0.20   599.79
# 1         1        2           8         2     1799.99      0.07  3599.91
# ...

# %%
orders = pd.read_sql("select * from orders",engine)
order_items=pd.read_sql("select*from order_items",engine)
cusromers = pd.read_sql("select*from customers",engine)

print(orders.head())
print(order_items.head())
print(customers.head())
# Out:
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  01-01-2016    03-01-2016   03-01-2016
# 1         2         1212             4  01-01-2016    04-01-2016   03-01-2016
# 2         3          523             4  02-01-2016    05-01-2016   03-01-2016
# 3         4          175             4  03-01-2016    04-01-2016   05-01-2016
# 4         5         1324             4  03-01-2016    06-01-2016   06-01-2016
#
#    store_id  staff_id order_details
# 0         1         2     DELIVERED
# 1         2         6     DELIVERED
# 2         2         7     DELIVERED
# 3         1         3     DELIVERED
# 4         2         6     DELIVERED
#    order_id  item_id  product_id  quantity  list_price  discount    sales  \
# 0         1        1          20         1      599.99      0.20   599.79
# 1         1        2           8         2     1799.99      0.07  3599.91
# ...

# %%
orders.info(),
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   int64
#  1   customer_id    1615 non-null   int64
#  2   order_status   1615 non-null   int64
#  3   order_date     1615 non-null   str
#  4   required_date  1615 non-null   str
#  5   shipped_date   1445 non-null   str
#  6   store_id       1615 non-null   int64
#  7   staff_id       1615 non-null   int64
#  8   order_details  1615 non-null   str
# dtypes: int64(5), str(4)
# memory usage: 113.7 KB
# (None,)

# %%
orders.describe()
order_items.info()
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      4722 non-null   int64
#  1   item_id       4722 non-null   int64
#  2   product_id    4722 non-null   int64
#  3   quantity      4722 non-null   int64
#  4   list_price    4722 non-null   float64
#  5   discount      4722 non-null   float64
#  6   sales         4722 non-null   float64
#  7   product_name  4722 non-null   str
# dtypes: float64(3), int64(4), str(1)
# memory usage: 295.3 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   str
#  2   last_name    1445 non-null   str
#  3   phone        1445 non-null   str
#  4   email        1445 non-null   str
# ...

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   int64
#  1   customer_id    1615 non-null   int64
#  2   order_status   1615 non-null   int64
#  3   order_date     1615 non-null   str
#  4   required_date  1615 non-null   str
#  5   shipped_date   1445 non-null   str
#  6   store_id       1615 non-null   int64
#  7   staff_id       1615 non-null   int64
#  8   order_details  1615 non-null   str
# dtypes: int64(5), str(4)
# memory usage: 113.7 KB

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      4722 non-null   int64
#  1   item_id       4722 non-null   int64
#  2   product_id    4722 non-null   int64
#  3   quantity      4722 non-null   int64
#  4   list_price    4722 non-null   float64
#  5   discount      4722 non-null   float64
#  6   sales         4722 non-null   float64
#  7   product_name  4722 non-null   str
# dtypes: float64(3), int64(4), str(1)
# memory usage: 295.3 KB

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   str
#  2   last_name    1445 non-null   str
#  3   phone        1445 non-null   str
#  4   email        1445 non-null   str
#  5   street       1445 non-null   str
#  6   city         1445 non-null   str
#  7   state        1445 non-null   str
#  8   zip_code     1445 non-null   int64
# dtypes: int64(2), str(7)
# memory usage: 101.7 KB

# %%
order_items.describe(),
# Out:
# (          order_id      item_id   product_id     quantity    list_price  \
#  count  4722.000000  4722.000000  4722.000000  4722.000000   4722.000000
#  mean    821.265354     2.262601    59.366158     1.498941   1212.707872
#  std     465.152168     1.199129    67.312708     0.500052   1352.798257
#  min       1.000000     1.000000     2.000000     1.000000     89.990000
#  25%     423.250000     1.000000    14.000000     1.000000    429.000000
#  50%     828.500000     2.000000    28.000000     1.000000    599.990000
#  75%    1226.000000     3.000000    84.000000     2.000000   1549.000000
#  max    1615.000000     5.000000   315.000000     2.000000  11999.990000
#
#            discount         sales
#  count  4722.000000   4722.000000
#  mean      0.105373   1816.707181
#  std       0.058119   2228.162327
#  min       0.050000     89.790000
#  25%       0.050000    539.780000
#  50%       0.085000    939.910000
#  75%       0.200000   1999.910000
# ...

# %%
customers.describe()
# Out:
#        customer_id      zip_code
# count  1445.000000   1445.000000
# mean    723.000000  34200.015225
# std     417.279882  34733.933551
# min       1.000000  10002.000000
# 25%     362.000000  11419.000000
# 50%     723.000000  11967.000000
# 75%    1084.000000  76110.000000
# max    1445.000000  95993.000000

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_date',
#        'required_date', 'shipped_date', 'store_id', 'staff_id',
#        'order_details'],
#       dtype='str')

# %%
orders["order_status"].value_counts().head(10)
# Out:
# order_status
# 4    1445
# 2      63
# 1      62
# 3      45
# Name: count, dtype: int64

# %%
orders["order_details"].value_counts()
# Out:
# order_details
# DELIVERED    1445
# PENDING       170
# Name: count, dtype: int64

# %%
product_sales = (
    order_items.groupby("product_name")["sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(product_sales)
# Out:
# product_name
# Trek Slash 8 27.5 - 2016                 615988.44
# Trek Conduit+ - 2016                     434988.03
# Trek Fuel EX 8 29 - 2016                 414687.65
# Surly Straggler 650b - 2016              253818.72
# Trek Domane SLR 6 Disc - 2017            236496.56
# Surly Straggler - 2016                   227692.57
# Trek Remedy 29 Carbon Frameset - 2016    224990.38
# Trek Powerfly 8 FS Plus - 2017           204997.40
# Trek Madone 9.2 - 2017                   194996.99
# Trek Silque SLR 8 Women's - 2017         188498.29
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt

product_sales.plot(kind='barh', figsize=(10, 6))

plt.xlabel('Total Sales')
plt.ylabel('Product')
plt.title('Top 10 Products by Sales')
plt.gca().invert_yaxis()
plt.show()

# %%
store_sales = (
    order_items
    .merge(orders[['order_id', 'store_id']], on='order_id')
    .groupby('store_id')['sales']
    .sum()
    .sort_values(ascending=False)
)

store_sales
# Out:
# store_id
# 2    5825901.85
# 1    1790041.05
# 3     962548.41
# Name: sales, dtype: float64

# %%
store_sales.plot(kind='bar', figsize=(8, 5))

plt.title('Total Sales by Store')
plt.xlabel('Store ID')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.show()

# %%
sales = order_items.merge(
    orders[['order_id', 'order_date']],
    on='order_id',
    how='inner'
)

sales['order_date'] = pd.to_datetime(
    sales['order_date'],
    dayfirst=True
)

monthly_sales = (
    sales
    .groupby(sales['order_date'].dt.to_period('M'))['sales']
    .sum()
)

monthly_sales
# Out:
# order_date
# 2016-01    241168.89
# 2016-02    175751.54
# 2016-03    202142.53
# 2016-04    187211.10
# 2016-05    228686.42
# 2016-06    231107.35
# 2016-07    222838.97
# 2016-08    253113.83
# 2016-09    303262.75
# 2016-10    235034.52
# 2016-11    205301.95
# 2016-12    223680.12
# 2017-01    316938.86
# 2017-02    348721.08
# 2017-03    348155.60
# 2017-04    254085.96
# 2017-05    297737.38
# 2017-06    419871.37
# 2017-07    255709.04
# 2017-08    322533.23
# 2017-09    329373.25
# 2017-10    345296.73
# 2017-11    315863.82
# 2017-12    291007.41
# 2018-01    426284.76
# 2018-02    223930.38
# 2018-03    406681.01
# 2018-04    909139.66
# 2018-06       209.89
# 2018-07     12949.02
# 2018-08     10255.94
# 2018-09      9949.59
# 2018-10      4219.40
# 2018-11     12278.47
# 2018-12      7999.49
# Freq: M, Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt

monthly_sales.plot(
    kind='line',
    figsize=(12, 6),
    marker='o'
)

plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales Trend')
plt.grid(True)
plt.show()

# %%
status_counts = orders['order_status'].value_counts()

status_counts
# Out:
# order_status
# 4    1445
# 2      63
# 1      62
# 3      45
# Name: count, dtype: int64

# %%
print(orders.columns.tolist())
# Out:
# ['order_id', 'customer_id', 'order_status', 'order_date', 'required_date', 'shipped_date', 'store_id', 'staff_id', 'order_details']

# %%
import matplotlib.pyplot as plt

status_counts.plot(
    kind='bar',
    figsize=(7, 5)
)

plt.title('Order Status Distribution')
plt.xlabel('Order Status')
plt.ylabel('Number of Orders')
plt.xticks(rotation=0)
plt.show()

# %%
customer_sales = (
    customers[['customer_id', 'first_name', 'last_name']]
    .merge(
        orders[['order_id', 'customer_id']],
        on='customer_id'
    )
    .merge(
        order_items[['order_id', 'sales']],
        on='order_id'
    )
)

customer_sales.head()
# Out:
#    customer_id first_name last_name  order_id    sales
# 0            1      Debra     Burks       599  5999.93
# 1            1      Debra     Burks       599   539.78
# 2            1      Debra     Burks       599   299.92
# 3            1      Debra     Burks       599  3097.90
# 4            1      Debra     Burks      1555  1099.88

# %%
import matplotlib.pyplot as plt

# %%
orders["customer_id"].value_counts().head(10).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 10 Customers by Number of Orders")
plt.xlabel("Customer ID")
plt.ylabel("Number of Orders")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(
    x="customer_id",
    data=orders
)

plt.xticks(rotation=90)
plt.title("orders by customer")
plt.show()

# %%
orders["customer_id"].value_counts().head(10).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 10 Customers by Number of Orders")
plt.xlabel("Customer ID")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
top_customers = orders["customer_id"].value_counts().head(10)

sns.barplot(
    x=top_customers.index.astype(str),
    y=top_customers.values
)

plt.title("Top 10 Customers by Number of Orders")
plt.xlabel("Customer ID")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
rfm_data = sales.groupby("customer_id").agg(
    Recency=(
        "order_date",
        lambda x: (reference_date - x.max()).days
    ),
    Frequency=(
        "order_id",
        "nunique"
    ),
    Monetary=(
        "total_amount",
        "sum"
    )
).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 rfm_data = sales.groupby("customer_id").agg(
#       2     Recency=(
#       3         "order_date",
#       4         lambda x: (reference_date - x.max()).days
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
# ...

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:1234@localhost:3306/sales_data"
)

# %%
orders = pd.read_sql("SELECT * FROM orders", engine)
order_items = pd.read_sql("SELECT * FROM order_items", engine)
customers = pd.read_sql("SELECT * FROM customers", engine)

# %%
print("Orders:")
display(orders.head())

print("Order Items:")
display(order_items.head())

print("Customers:")
display(customers.head())
# Out:
# Orders:
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  01-01-2016    03-01-2016   03-01-2016
# 1         2         1212             4  01-01-2016    04-01-2016   03-01-2016
# 2         3          523             4  02-01-2016    05-01-2016   03-01-2016
# 3         4          175             4  03-01-2016    04-01-2016   05-01-2016
# 4         5         1324             4  03-01-2016    06-01-2016   06-01-2016
#
#    store_id  staff_id order_details
# 0         1         2     DELIVERED
# 1         2         6     DELIVERED
# 2         2         7     DELIVERED
# 3         1         3     DELIVERED
# 4         2         6     DELIVERED
# Order Items:
#    order_id  item_id  product_id  quantity  list_price  discount    sales  \
# 0         1        1          20         1      599.99      0.20   599.79
# 1         1        2           8         2     1799.99      0.07  3599.91
# ...

# %%
print("Orders columns:")
print(orders.columns)

print("Order Items columns:")
print(order_items.columns)

print("Customers columns:")
print(customers.columns)
# Out:
# Orders columns:
# Index(['order_id', 'customer_id', 'order_status', 'order_date',
#        'required_date', 'shipped_date', 'store_id', 'staff_id',
#        'order_details'],
#       dtype='str')
# Order Items columns:
# Index(['order_id', 'item_id', 'product_id', 'quantity', 'list_price',
#        'discount', 'sales', 'product_name'],
#       dtype='str')
# Customers columns:
# Index(['customer_id', 'first_name', 'last_name', 'phone', 'email', 'street',
#        'city', 'state', 'zip_code'],
#       dtype='str')

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("1234")

engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost:3306/sales_data"
)

print("Connection engine created successfully!")
# Out:
# Connection engine created successfully!

# %%
orders = pd.read_sql("SELECT * FROM orders", engine)
order_items = pd.read_sql("SELECT * FROM order_items", engine)
customers = pd.read_sql("SELECT * FROM customers", engine)

print(orders.shape)
print(order_items.shape)
print(customers.shape)
# Out:
# (1615, 9)
# (4722, 8)
# (1445, 9)

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'], errors='coerce')

# %%
print(orders['order_date'].dtype)
# Out:
# datetime64[us]

# %%
# RFM Analysis

reference_date = orders['order_date'].max() + pd.Timedelta(days=1)

rfm_data = orders.groupby('customer_id').agg(
    Recency=('order_date', lambda x: (reference_date - x.max()).days),
    Frequency=('order_id', 'nunique')
).reset_index()

rfm_data.head()
# Out:
#    customer_id  Recency  Frequency
# 0            1    817.0          3
# 1            2     95.0          3
# 2            3    187.0          3
# 3            4    524.0          3
# 4            5    793.0          3

# %%
monetary = order_items.groupby('order_id')['sales'].sum().reset_index()

rfm_data = rfm_data.merge(
    orders[['order_id', 'customer_id']],
    on='customer_id',
    how='left'
)

rfm_data = rfm_data.merge(
    monetary,
    on='order_id',
    how='left'
)

rfm_data = rfm_data.groupby('customer_id').agg(
    Recency=('Recency', 'first'),
    Frequency=('Frequency', 'first'),
    Monetary=('sales', 'sum')
).reset_index()

rfm_data.head()
# Out:
#    customer_id  Recency  Frequency  Monetary
# 0            1    817.0          3  30644.78
# 1            2     95.0          3  21652.87
# 2            3    187.0          3  26248.66
# 3            4    524.0          3  24197.81
# 4            5    793.0          3  19442.01

# %%
rfm_data['R_Score'] = pd.qcut(
    rfm_data['Recency'],
    5,
    labels=[5, 4, 3, 2, 1]
)

rfm_data['F_Score'] = pd.qcut(
    rfm_data['Frequency'].rank(method='first'),
    5,
    labels=[1, 2, 3, 4, 5]
)

rfm_data['M_Score'] = pd.qcut(
    rfm_data['Monetary'],
    5,
    labels=[1, 2, 3, 4, 5]
)

rfm_data['RFM_Score'] = (
    rfm_data['R_Score'].astype(str) +
    rfm_data['F_Score'].astype(str) +
    rfm_data['M_Score'].astype(str)
)

rfm_data.head()
# Out:
#    customer_id  Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score
# 0            1    817.0          3  30644.78       2       5       5     2.055
# 1            2     95.0          3  21652.87       5       5       5     5.055
# 2            3    187.0          3  26248.66       5       5       5     5.055
# 3            4    524.0          3  24197.81       4       5       5     4.055
# 4            5    793.0          3  19442.01       2       5       5     2.055

# %%
rfm_data['R_Score'] = pd.qcut(
    rfm_data['Recency'],
    5,
    labels=[5, 4, 3, 2, 1]
).astype(int)

rfm_data['F_Score'] = pd.qcut(
    rfm_data['Frequency'].rank(method='first'),
    5,
    labels=[1, 2, 3, 4, 5]
).astype(int)

rfm_data['M_Score'] = pd.qcut(
    rfm_data['Monetary'],
    5,
    labels=[1, 2, 3, 4, 5]
).astype(int)

rfm_data['RFM_Score'] = (
    rfm_data['R_Score'].astype(str) +
    rfm_data['F_Score'].astype(str) +
    rfm_data['M_Score'].astype(str)
).astype(int)

rfm_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 5
#       1 rfm_data['R_Score'] = pd.qcut(
#       2     rfm_data['Recency'],
#       3     5,
#       4     labels=[5, 4, 3, 2, 1]
# ----> 5 ).astype(int)
#       6
#       7 rfm_data['F_Score'] = pd.qcut(
#       8     rfm_data['Frequency'].rank(method='first'),
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6529, in NDFrame.astype(self, dtype, copy, errors)
#    6525             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6526
#    6527         else:
#    6528             # else, only a single dtype is given
# -> 6529             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6530             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
rfm_data[['Recency', 'Frequency', 'Monetary']].isnull().sum()
# Out:
# Recency      850
# Frequency      0
# Monetary       0
# dtype: int64

# %%
rfm_data = rfm_data.dropna(subset=['Recency', 'Frequency', 'Monetary']).copy()

# %%
rfm_data['R_Score'] = pd.qcut(
    rfm_data['Recency'],
    5,
    labels=[5, 4, 3, 2, 1]
).astype(int)

rfm_data['F_Score'] = pd.qcut(
    rfm_data['Frequency'].rank(method='first'),
    5,
    labels=[1, 2, 3, 4, 5]
).astype(int)

rfm_data['M_Score'] = pd.qcut(
    rfm_data['Monetary'],
    5,
    labels=[1, 2, 3, 4, 5]
).astype(int)

rfm_data['RFM_Score'] = (
    rfm_data['R_Score'].astype(str) +
    rfm_data['F_Score'].astype(str) +
    rfm_data['M_Score'].astype(str)
).astype(int)

rfm_data.head()
# Out:
#    customer_id  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0            1    817.0          3  30644.78        2        5        5
# 1            2     95.0          3  21652.87        5        5        5
# 2            3    187.0          3  26248.66        5        5        5
# 3            4    524.0          3  24197.81        4        5        5
# 4            5    793.0          3  19442.01        2        5        5
#
#    RFM_Score         Segment
# 0        255  Lost Customers
# 1        555  Lost Customers
# 2        555  Lost Customers
# 3        455  Lost Customers
# 4        255  Lost Customers

# %%
rfm_data['RFM_Score'] = pd.to_numeric(
    rfm_data['RFM_Score'],
    errors='coerce'
)

# %%
def segment_customer(row):
    if row['RFM_Score'] >= 444:
        return 'Champions'
    elif row['RFM_Score'] >= 333:
        return 'Loyal Customers'
    elif row['RFM_Score'] >= 222:
        return 'Potential Loyalists'
    elif row['RFM_Score'] >= 111:
        return 'At Risk'
    else:
        return 'Lost Customers'

rfm_data['Segment'] = rfm_data.apply(segment_customer, axis=1)

rfm_data.head()
# Out:
#    customer_id  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0            1    817.0          3  30644.78        2        5        5
# 1            2     95.0          3  21652.87        5        5        5
# 2            3    187.0          3  26248.66        5        5        5
# 3            4    524.0          3  24197.81        4        5        5
# 4            5    793.0          3  19442.01        2        5        5
#
#    RFM_Score              Segment
# 0        255  Potential Loyalists
# 1        555            Champions
# 2        555            Champions
# 3        455            Champions
# 4        255  Potential Loyalists

# %%
rfm_data['Segment'].value_counts()
# Out:
# Segment
# Potential Loyalists    155
# Champions              148
# At Risk                147
# Loyal Customers        145
# Name: count, dtype: int64

# %%
customer_segments = rfm_data[
    ['customer_id', 'RFM_Score', 'Segment']
].copy()

customer_segments.head()
# Out:
#    customer_id  RFM_Score              Segment
# 0            1        255  Potential Loyalists
# 1            2        555            Champions
# 2            3        555            Champions
# 3            4        455            Champions
# 4            5        255  Potential Loyalists

# %%
# Export RFM Segmentation Results to MySQL

rfm_data.to_sql(
    'customer_segments',
    con=engine,
    if_exists='replace',
    index=False
)

print("Customer segmentation exported successfully!")
# Out:
# Customer segmentation exported successfully!

# %%
check = pd.read_sql(
    "SELECT * FROM customer_segments LIMIT 10",
    engine
)

check
# Out:
#    customer_id  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0            1    817.0          3  30644.78        2        5        5
# 1            2     95.0          3  21652.87        5        5        5
# 2            3    187.0          3  26248.66        5        5        5
# 3            4    524.0          3  24197.81        4        5        5
# 4            5    793.0          3  19442.01        2        5        5
# 5            6    182.0          3  35856.83        5        5        5
# 6            7   1010.0          3   7707.64        1        5        4
# 7            8      4.0          3   2603.58        5        5        2
# 8           10    522.0          3  37800.42        4        5        5
# 9           11     97.0          3   4079.49        5        5        3
#
#    RFM_Score              Segment
# 0        255  Potential Loyalists
# 1        555            Champions
# 2        555            Champions
# 3        455            Champions
# ...

# %%
# BUSINESS INSIGHTS CALCULATIONS

# Total Sales
total_sales = orders['sales_amount'].sum()

# Product Sales
product_sales = orders.groupby('product_name')['sales_amount'].sum().sort_values(ascending=False)

# Category Sales
category_sales = orders.groupby('category')['sales_amount'].sum().sort_values(ascending=False)

# Brand Sales
brand_sales = orders.groupby('brand')['sales_amount'].sum().sort_values(ascending=False)

# Average Discount
avg_discount = orders['discount'].mean()

# Business Insights
print("BUSINESS INSIGHTS")
print("=" * 50)

print("1. Total Sales:", round(total_sales, 2))
print("2. Best Selling Product by Revenue:", product_sales.index[0])
print("3. Best Performing Category:", category_sales.index[0])
print("4. Best Performing Brand:", brand_sales.index[0])
print("5. Average Discount:", round(avg_discount * 100, 2), "%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(orders.columns.tolist())
# Out:
# ['order_id', 'customer_id', 'order_status', 'order_date', 'required_date', 'shipped_date', 'store_id', 'staff_id', 'order_details']

# %%
print(orders['order_details'].head(10))
# Out:
# 0    DELIVERED
# 1    DELIVERED
# 2    DELIVERED
# 3    DELIVERED
# 4    DELIVERED
# 5    DELIVERED
# 6    DELIVERED
# 7    DELIVERED
# 8    DELIVERED
# 9    DELIVERED
# Name: order_details, dtype: str

# %%
print(orders['order_details'].iloc[0])
# Out:
# DELIVERED

# %%
print(orders['order_details'].head())
# Out:
# 0    DELIVERED
# 1    DELIVERED
# 2    DELIVERED
# 3    DELIVERED
# 4    DELIVERED
# Name: order_details, dtype: str

# %%
print([name for name, obj in globals().items() 
       if hasattr(obj, 'columns')])
# Out:
# ['_', '__', 'orders', 'order_items', 'customers', 'cusromers', '_15', 'sales', 'customer_sales', '_28', 'rfm_data', '_46', 'monetary', '_47', '_48', '_50', 'customer_segments', '_52', '_57', '_58', '_61', 'check', '_63']

# %%
print(order_items.columns.tolist())
# Out:
# ['order_id', 'item_id', 'product_id', 'quantity', 'list_price', 'discount', 'sales', 'product_name']

# %%
# BUSINESS INSIGHTS CALCULATIONS

# Total Sales
total_sales = order_items['sales'].sum()

# Product Sales
product_sales = (
    order_items.groupby('product_name')['sales']
    .sum()
    .sort_values(ascending=False)
)

# Average Discount
avg_discount = order_items['discount'].mean()

# Business Insights
print("BUSINESS INSIGHTS")
print("=" * 50)

print("1. Total Sales:", round(total_sales, 2))
print("2. Best Selling Product by Revenue:", product_sales.index[0])
print("3. Average Discount:", round(avg_discount * 100, 2), "%")
# Out:
# BUSINESS INSIGHTS
# ...
# 1. Total Sales: 8578491.31
# 2. Best Selling Product by Revenue: Trek Slash 8 27.5 - 2016
# 3. Average Discount: 10.54 %
